-- %%
select * from dwh_retail.gold.calendar_master_gold;

select * from dwh_retail.silver.sales_silver; :param_1


select distinct dept_id,dept_name from dwh_retail.silver.merch_hier_silver

select * from dwh_retail.gold.store_master_gold

select * from dwh_retail.bronze.budget_bronze
select * from dwh_retail.silver.budget_silver
select * from dwh_retail.gold.agg_budget_gold order by 1,2,4;

select * from dwh_retail.bronze.budget_bronze
