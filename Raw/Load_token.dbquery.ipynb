-- %%
drop table dwh_retail.gold.load_token;

create table if not exists dwh_retail.gold.load_token(
    description string,
    TY integer,
    LY integer,
    LLY integer,
    LLLY integer
)
using delta;
----------------------------------
insert into dwh_retail.gold.load_token
(
    description,
    TY,
    LY,
    LLY,
    LLLY
)
values
(
    'History_3_years',
    --hardcoding as the sample data is old. Dynamic query is stated below
    2022,--year(current_date-1)
    2021,--year(current_date-1)-1
    2020,--year(current_date-1)-2
    2019--year(current_date-1)-3
    --"current_date-1" as its previous day's sales
);
