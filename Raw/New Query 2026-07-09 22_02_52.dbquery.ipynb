-- %%
create table if not exists dwh_retail.gold.load_token(
    description string,
    from_date date,
    to_date date
)
using delta;

update dwh_retail.gold.load_token 
set from_date = current_date-1,
to_date= current_date
where description = 'Load_token';

select * from dwh_retail.gold.load_token
